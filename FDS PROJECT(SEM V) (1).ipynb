# %% [markdown]
# TITlE:- Predictive Modeling for EARLY "DETECTION OF HEART DISEASE"

# %%
INTRODUCTION:-The Heart Disease Prediction dataset is a collection of data used to 
    develop models for predicting the likelihood of individuals having heart disease. 
    It typically includes various health-related features such as age, sex, blood pressure, 
    cholesterol levels, and other relevant parameters. Researchers and data scientists use this 
    dataset to build machine learning models that can analyze patterns and make predictions
    regarding the presence or absence of heart disease in individuals. 
    The goal is to enhance early detection and preventive measures for cardiovascular health.

# %%
DESCRIPTION OF DATASET:-The heart disease prediction dataset typically includes various health-related
  features such as age, sex, blood pressure, cholesterol levels, and various other medical parameters.
  Each entry in the dataset represents an individual's health profile, with a label indicating whether
  or not they have been diagnosed with heart disease.
  This type of dataset is commonly used for machine learning tasks to develop models that can predict
  the likelihood of heart disease based on these features.
  It's crucial for training and evaluating models aimed at assisting in early detection and prevention 
  of cardiovascular issues.

# %%
ANALYSIS:-There are mainly 4 steps to "Analysis" the Dataset.
(1)Step 1:-Load the Dataset
(2)Step 2:-Understand the Dataset
(3)Step 3:-Data Cleaning
(4)Step 4:-Data Visualization
For this exploratory study, we will use the Python Programming language and various libraries
like Pandas,matplotlib.pyplot and seaborn.

# %% [markdown]
# STEP 1:-Load the Dataset

# %%
#STEP 2:- Understand the Dataset
import pandas as pd
df=pd.read_csv("Heart_Disease_Prediction (1).csv")
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.shape
# Out:
# (270, 13)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium
# 0                        3         3
# 1                        0         7
# 2                        0         7
# ...

# %%
df.tail()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium
# 265                        0         7
# 266                        0         7
# 267                        0         3
# ...

# %%
df.sample(10)
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 216   63    0                3  135          252             0            2
# 218   54    1                3  120          258             0            2
# 193   35    1                4  126          282             0            2
# 37    59    1                1  160          273             0            2
# 247   65    0                3  155          269             0            0
# 159   66    0                4  178          228             1            0
# 192   54    1                2  108          309             0            0
# 76    45    1                4  104          208             0            2
# 238   47    1                3  138          257             0            2
# 210   59    1                1  170          288             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 216     172                0            0.0            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 27.6 KB

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# dtype: object

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
df.mean()
# Out:
# Age                         54.433333
# Sex                          0.677778
# Chest pain type              3.174074
# BP                         131.344444
# Cholesterol                249.659259
# FBS over 120                 0.148148
# EKG results                  1.022222
# Max HR                     149.677778
# Exercise angina              0.329630
# ST depression                1.050000
# Slope of ST                  1.585185
# Number of vessels fluro      0.670370
# Thallium                     4.696296
# dtype: float64

# %%
df.median()
# Out:
# Age                         55.0
# Sex                          1.0
# Chest pain type              3.0
# BP                         130.0
# Cholesterol                245.0
# FBS over 120                 0.0
# EKG results                  2.0
# Max HR                     153.5
# Exercise angina              0.0
# ST depression                0.8
# Slope of ST                  2.0
# Number of vessels fluro      0.0
# Thallium                     3.0
# dtype: float64

# %%
df.groupby('Chest pain type').agg(['mean','median'])
# Out:
#                        Age              Sex                 BP         \
#                       mean median      mean median        mean median
# Chest pain type
# 1                55.850000   59.0  0.800000    1.0  141.300000  142.5
# 2                51.261905   51.0  0.619048    1.0  128.261905  128.0
# 3                53.873418   54.0  0.594937    1.0  129.556962  130.0
# 4                55.589147   57.0  0.728682    1.0  131.899225  130.0
#
#                 Cholesterol        FBS over 120         ... Exercise angina  \
#                        mean median         mean median  ...            mean
# Chest pain type                                         ...
# 1                237.950000  234.0     0.250000    0.0  ...        0.200000
# 2                247.595238  245.0     0.119048    0.0  ...        0.095238
# 3                245.620253  240.0     0.215190    0.0  ...        0.139241
# 4                254.620155  254.0     0.100775    0.0  ...        0.542636
#
# ...

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 234    6
# 269    5
# 254    5
# 212    4
# 243    4
#       ..
# 313    1
# 564    1
# 221    1
# 306    1
# 192    1
# Name: count, Length: 144, dtype: int64

# %%
df.corr()
# Out:
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# Exercise angina          0.098297  0.180022         0.353160  0.082793
# ST depression            0.194234  0.097412         0.167244  0.222800
# Slope of ST              0.159774  0.050545         0.136900  0.142472
# Number of vessels fluro  0.356081  0.086830         0.225890  0.085697
# ...

# %% [markdown]
# STEP 3-Data Cleaning

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df["Chest pain type"].fillna(value=df["Chest pain type"].mean(),inplace=True)
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# STEP 4 :- Data Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.hist(df['Age'],color="blue")
plt.show()

# %%
sns.histplot(df,x="Age")
plt.show()
# Out:
# C:\Users\preet\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\preet\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#histogram for a specific feature
plt.figure(figsize=(10,7))
plt.hist(df["BP"])
plt.xlabel("BP")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Comparison between Chest pain type based on BP and Cholesterol')
sns.scatterplot(x=df['BP'],y=df['Cholesterol'],hue=df['Chest pain type'],s=50)
# Out:
# C:\Users\preet\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\preet\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\preet\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: title={'center': 'Comparison between Chest pain type based on BP and Cholesterol'}, xlabel='BP', ylabel='Cholesterol'>

# %%
plt.title("Max HR")
sns.boxplot(df["Max HR"],color='orange')
# Out:
# <Axes: title={'center': 'Max HR'}>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,11))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.scatter3D(df['BP'],df['Cholesterol'],df['FBS over 120'],edgecolor='black');
ax.set_xlabel("BP")
ax.set_ylabel("Cholesterol")
ax.set_zlabel("FBS over 120")
# Out:
# Text(0.5, 0, 'FBS over 120')

# %%
CONCLUSIONS:-
The above Exploratory Data Analysis on the Heart_Disease_Predication dataset given significant
information and insight into the dataset.We have obtained basic statistical information as well as 
deeper understanding of the relationship between heart disease predication through visualization.
(1) The dataset is balanced.
(2) A strong correaltion is present between BP and Cholesterol.
(3) To draw a conclusion from a heart disease prediction dataset, you typically need 
    to analyze various factors and model performance. 
(4) Consider evaluating features,importance, assessing model accuracy, precision, and recall.
(5) Additionally, check for overfitting or underfitting. 
(6) Interpretation of results should involve collaboration with domain experts
    for a comprehensive understanding.
